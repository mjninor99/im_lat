# %% [markdown]
# # Data Engineer Challenge - Análisis de Tweets
#
# Este notebook contiene la implementación y análisis de las tres tareas del desafío, con enfoques optimizados para tiempo y memoria.
#
# ## Supuestos y Consideraciones
#
# 1. **Estructura de datos**: Los tweets están en formato JSON, uno por línea (JSONL)
# 2. **Codificación**: Todos los archivos utilizan codificación UTF-8
# 4. **Manejo de errores**: Se ignoran tweets con formato inválido o campos faltantes
# 5. **Emojis**: Se utilizan tanto variantes base como con modificadores de tono de piel

# %% [markdown]
# ## Instalación de Dependencias

# %%
# %pip install memory-profiler==0.61
# Out:
# Python(36009) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: /usr/local/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install setuptools
# Out:
# Python(36010) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: /usr/local/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install emoji
# Out:
# Python(36011) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: /usr/local/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
file_path = "farmers-protest-tweets-2021-2-4.json"

# %% [markdown]
# # Tarea 1: Top 10 fechas con más tweets y usuario más activo por fecha
#
# ## Objetivo
# Encontrar las 10 fechas con mayor cantidad de tweets y, para cada una de esas fechas, identificar el usuario (username) que más publicaciones tiene.
#
# ## Enfoque Optimizado para Tiempo (q1_time)
#
# **Estrategia:**
# - Utiliza Counter y defaultdict de collections para operaciones rápidas
# - Almacena todos los datos en memoria para acceso rápido
# - Usa most_common() que es altamente optimizado en C
#
# **Ventajas:**
# - Operaciones de conteo muy rápidas
# - Menos overhead en el procesamiento
# - Ideal para datasets que caben en memoria

# %%
import time  # Recargar el módulo para obtener la versión más reciente
from q1_time import q1_time, q1_time_fast
from q1_memory import q1_memory

# %% [markdown]
# ### Medición de Tiempo

# %%
# Medición de memoria
print("=== Medición de Memoria (q1_) ===")
# %memit q1_time(file_path)
# Out:
# === Medición de Tiempo (q1_time) ===
# Tiempo de ejecución: 4.8036 segundos

# %%
# Medición de tiempo
print("\n=== Medición de Tiempo (q1_memory.py) ===")
start = time.perf_counter()
result_q1_memory = q1_memory(file_path)
end = time.perf_counter()

print(f"Tiempo de ejecución: {end - start:.4f} segundos")
# Out:
# === Medición de Tiempo (q1_memory.py) ===
# Tiempo de ejecución: 5.3529 segundos

# %% [markdown]
# ## Enfoque Optimizado para Memoria (q1_memory)
#
# **Estrategia:**
# - Utiliza diccionarios simples en lugar de Counter para reducir overhead
# - Procesa línea por línea sin cargar todo en memoria
# - Elimina referencias explícitamente con del para liberar memoria
# - Ordena manualmente solo al final
#
# **Ventajas:**
# - Menor consumo de memoria
# - Ideal para datasets muy grandes o sistemas con memoria limitada
# - Procesamiento streaming eficiente

# %% [markdown]
# ### Medición de Memoria

# %%
# Medición de memoria
print("=== Medición de Memoria (q1_memory) ===")
# %memit q1_memory(file_path)
# Out:
# === Medición de Memoria (q1_memory) ===
# Python(47444) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# peak memory: 85.69 MiB, increment: 0.43 MiB

# %%
# Medición de tiempo
print("\n=== Medición de Tiempo (q1_memory) ===")
start = time.perf_counter()
result_q1_memory = q1_memory(file_path)
end = time.perf_counter()

print(f"Tiempo de ejecución: {end - start:.4f} segundos")
print(f"\nTop 10 fechas con más tweets y usuario más activo por fecha:")
for i, (date, username) in enumerate(result_q1_memory, 1):
    print(f"{i}. {date}: {username}")
# Out:
# === Medición de Tiempo (q1_memory) ===
# Tiempo de ejecución: 4.8331 segundos
#
# Top 10 fechas con más tweets y usuario más activo por fecha:
# 1. 2021-02-12: RanbirS00614606
# 2. 2021-02-13: MaanDee08215437
# 3. 2021-02-17: RaaJVinderkaur
# 4. 2021-02-16: jot__b
# 5. 2021-02-14: rebelpacifist
# 6. 2021-02-18: neetuanjle_nitu
# 7. 2021-02-15: jot__b
# 8. 2021-02-20: MangalJ23056160
# 9. 2021-02-23: Surrypuria
# 10. 2021-02-19: Preetm91

# %% [markdown]
# # Tarea 2: Top 10 emojis más usados
#
# ## Objetivo
# Identificar los 10 emojis más utilizados en los tweets junto con su conteo.
#
# ## Enfoque Optimizado para Tiempo (q2_time)
#
# **Estrategia:**
# - Utiliza Counter para conteo eficiente
# - Filtro rápido de líneas inválidas antes de parsear JSON
# - Actualización directa del contador sin loops adicionales
# - Usa most_common() optimizado
#
# **Ventajas:**
# - Procesamiento muy rápido
# - Menos operaciones intermedias
# - Ideal cuando la memoria no es limitante

# %%
from q2_time import q2_time
from q2_memory import q2_memory

# %%
# Medición de memoria
print("=== Medición de Memoria (q2_) ===")
# %memit q2_time(file_path)
# Out:
# === Medición de Memoria (q2_) ===
# Python(45070) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# peak memory: 82.65 MiB, increment: 1.62 MiB

# %%
# Medición de tiempo
print("\n=== Medición de Tiempo (q2_time) ===")
start = time.perf_counter()
result_q2_time = q2_time(file_path)
end = time.perf_counter()

print(f"Tiempo de ejecución: {end - start:.4f} segundos")
# Out:
# === Medición de Tiempo (q2_time) ===
# Tiempo de ejecución: 23.3917 segundos

# %% [markdown]
# ## Enfoque Optimizado para Memoria (q2_memory)
#
# **Estrategia:**
# - Utiliza diccionario simple en lugar de Counter
# - Elimina referencias explícitamente después de procesar cada tweet
# - Ordena solo al final cuando es necesario
# - Procesamiento streaming línea por línea
#
# **Ventajas:**
# - Menor consumo de memoria
# - Liberación inmediata de objetos procesados
# - Ideal para sistemas con restricciones de memoria

# %%
# Medición de memoria
print("=== Medición de Memoria (q2_memory) ===")
# %memit q2_memory(file_path)
# Out:
# === Medición de Memoria (q2_memory) ===
# Python(46011) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# peak memory: 82.31 MiB, increment: 0.31 MiB

# %%
# Medición de tiempo
print("\n=== Medición de Tiempo (q2_memory) ===")
start = time.perf_counter()
result_q2_memory = q2_memory(file_path)
end = time.perf_counter()

print(f"Tiempo de ejecución: {end - start:.4f} segundos")
print(f"\nTop 10 emojis más usados:")
for i, (emoji_char, count) in enumerate(result_q2_memory, 1):
    print(f"{i}. {emoji_char}: {count} veces")
# Out:
# === Medición de Tiempo (q2_memory) ===
# Tiempo de ejecución: 18.8801 segundos
#
# Top 10 emojis más usados:
# 1. 🙏: 5049 veces
# 2. 😂: 3072 veces
# 3. 🚜: 2972 veces
# 4. 🌾: 2182 veces
# 5. 🇮🇳: 2086 veces
# 6. 🤣: 1668 veces
# 7. ✊: 1651 veces
# 8. ❤️: 1382 veces
# 9. 🙏🏻: 1317 veces
# 10. 💚: 1040 veces

# %% [markdown]
# # Tarea 3: Top 10 usuarios más influyentes por menciones
#
# ## Objetivo
# Identificar los 10 usuarios (username) más influyentes basándose en el número de menciones (@) que reciben en los tweets.
#
# ## Enfoque Optimizado para Tiempo (q3_time)
#
# **Estrategia:**
# - Utiliza Counter para conteo eficiente
# - Prioriza el campo mentionedUsers cuando está disponible (más confiable)
# - Fallback a extracción por regex del contenido cuando no está disponible
# - Usa most_common() optimizado
#
# **Ventajas:**
# - Procesamiento rápido con estructuras optimizadas
# - Manejo eficiente de ambos casos (campo disponible o no)
# - Ideal cuando la memoria no es limitante

# %%
from q3_time import q3_time
from q3_memory import q3_memory

# %%
# Medición de memoria
print("=== Medición de Memoria (q3_time) ===")
# %memit q3_time(file_path)
# Out:
# === Medición de Memoria (q3_time) ===
# Python(44424) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# peak memory: 83.95 MiB, increment: 1.12 MiB

# %%
# Medición de tiempo
print("\n=== Medición de Tiempo (q3_time) ===")
start = time.perf_counter()
result_q3_time = q3_time(file_path)
end = time.perf_counter()

print(f"Tiempo de ejecución: {end - start:.4f} segundos")
print(f"\nTop 10 usuarios más mencionados:")
for i, (username, count) in enumerate(result_q3_time, 1):
    print(f"{i}. @{username}: {count} menciones")
# Out:
# === Medición de Tiempo (q3_time) ===
# Tiempo de ejecución: 5.5041 segundos
#
# Top 10 usuarios más mencionados:
# 1. @narendramodi: 2265 menciones
# 2. @Kisanektamorcha: 1840 menciones
# 3. @RakeshTikaitBKU: 1644 menciones
# 4. @PMOIndia: 1427 menciones
# 5. @RahulGandhi: 1146 menciones
# 6. @GretaThunberg: 1048 menciones
# 7. @RaviSinghKA: 1019 menciones
# 8. @rihanna: 986 menciones
# 9. @UNHumanRights: 962 menciones
# 10. @meenaharris: 926 menciones

# %% [markdown]
# ## Enfoque Optimizado para Memoria (`q3_memory`)
#
# **Estrategia:**
# - Utiliza diccionario simple en lugar de `Counter`
# - Elimina referencias explícitamente después de procesar cada tweet
# - Mismo enfoque de priorización: `mentionedUsers` primero, regex como fallback
# - Ordena solo al final cuando es necesario
#
# **Ventajas:**
# - Menor consumo de memoria
# - Liberación inmediata de objetos procesados
# - Ideal para sistemas con restricciones de memoria

# %%
from q3_memory import q3_memory

# Medición de memoria
print("=== Medición de Memoria (q3_memory) ===")
# %memit q3_memory(file_path)
# Out:
# === Medición de Memoria (q3_memory) ===
# Python(44467) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# peak memory: 84.29 MiB, increment: 0.32 MiB

# %%
# Medición de tiempo
print("\n=== Medición de Tiempo (q3_memory) ===")
start = time.perf_counter()
result_q3_memory = q3_memory(file_path)
end = time.perf_counter()

print(f"Tiempo de ejecución: {end - start:.4f} segundos")
print(f"\nTop 10 usuarios más mencionados:")
for i, (username, count) in enumerate(result_q3_memory, 1):
    print(f"{i}. @{username}: {count} menciones")

# Verificación de consistencia
print(f"\n=== Verificación ===")
print(f"¿Resultados idénticos? {result_q3_time == result_q3_memory}")
# Out:
# === Medición de Tiempo (q3_memory) ===
# Tiempo de ejecución: 5.9873 segundos
#
# Top 10 usuarios más mencionados:
# 1. @narendramodi: 2265 menciones
# 2. @Kisanektamorcha: 1840 menciones
# 3. @RakeshTikaitBKU: 1644 menciones
# 4. @PMOIndia: 1427 menciones
# 5. @RahulGandhi: 1146 menciones
# 6. @GretaThunberg: 1048 menciones
# 7. @RaviSinghKA: 1019 menciones
# 8. @rihanna: 986 menciones
# 9. @UNHumanRights: 962 menciones
# 10. @meenaharris: 926 menciones
#
# === Verificación ===
# ¿Resultados idénticos? True

# %% [markdown]
# #Mejores propuestas
#
# - Uso de GCS para almacenar el archivo y hacer lectura desde bucket
# - Exportar información a dos tablas de BigQuery, una de tweets y otra con los usuarios para q1 y q2
# - Uso de Dataflow
# - Excepciones de lectura del bucket
